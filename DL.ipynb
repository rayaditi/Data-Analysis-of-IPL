# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
matches=pd.read_csv("/content/drive/MyDrive/matches.csv")
matches.shape
matches.head()
# Out:
#    id  season       city  ...         umpire1        umpire2 umpire3
# 0   1    2017  Hyderabad  ...     AY Dandekar       NJ Llong     NaN
# 1   2    2017       Pune  ...  A Nand Kishore         S Ravi     NaN
# 2   3    2017     Rajkot  ...     Nitin Menon      CK Nandan     NaN
# 3   4    2017     Indore  ...    AK Chaudhary  C Shamshuddin     NaN
# 4   5    2017  Bangalore  ...             NaN            NaN     NaN
#
# [5 rows x 18 columns]

# %%
deliveries=pd.read_csv("/content/drive/MyDrive/deliveries.csv")
deliveries.shape
deliveries.head()
# Out:
#    match_id  inning  ... dismissal_kind fielder
# 0         1       1  ...            NaN     NaN
# 1         1       1  ...            NaN     NaN
# 2         1       1  ...            NaN     NaN
# 3         1       1  ...            NaN     NaN
# 4         1       1  ...            NaN     NaN
#
# [5 rows x 21 columns]

# %%
deliveries= deliveries.rename(columns={'match_id': 'id'})
deliveries.head()
# Out:
#    id  inning         batting_team  ... player_dismissed  dismissal_kind  fielder
# 0   1       1  Sunrisers Hyderabad  ...              NaN             NaN      NaN
# 1   1       1  Sunrisers Hyderabad  ...              NaN             NaN      NaN
# 2   1       1  Sunrisers Hyderabad  ...              NaN             NaN      NaN
# 3   1       1  Sunrisers Hyderabad  ...              NaN             NaN      NaN
# 4   1       1  Sunrisers Hyderabad  ...              NaN             NaN      NaN
#
# [5 rows x 21 columns]

# %%
data = pd.merge(left=matches, right=deliveries, on='id', how='right')
data.head()
# Out:
#    id  season       city  ... player_dismissed dismissal_kind fielder
# 0   1    2017  Hyderabad  ...              NaN            NaN     NaN
# 1   1    2017  Hyderabad  ...              NaN            NaN     NaN
# 2   1    2017  Hyderabad  ...              NaN            NaN     NaN
# 3   1    2017  Hyderabad  ...              NaN            NaN     NaN
# 4   1    2017  Hyderabad  ...              NaN            NaN     NaN
#
# [5 rows x 38 columns]

# %%
data.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# id                       0
# season                   0
# city                  1700
# date                     0
# team1                    0
# team2                    0
# toss_winner              0
# toss_decision            0
# result                   0
# dl_applied               0
# winner                 372
# win_by_runs              0
# win_by_wickets           0
# player_of_match        372
# venue                    0
# umpire1                500
# umpire2                500
# umpire3             150712
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    170244
# dismissal_kind      170244
# fielder             172630
# dtype: int64

# %%
data.drop(['umpire3'],axis='columns',inplace=True)
data.drop(['dismissal_kind'],axis='columns',inplace=True)
data.drop(['fielder'],axis='columns',inplace=True)

# %%
data['date'] = pd.to_datetime(data['date'])
data['year'] = pd.DatetimeIndex(data['date']).year
data['over'] = data['over']+1
data.head()
# Out:
#    id  season       city  ... total_runs player_dismissed  year
# 0   1    2017  Hyderabad  ...          0              NaN  2017
# 1   1    2017  Hyderabad  ...          0              NaN  2017
# 2   1    2017  Hyderabad  ...          4              NaN  2017
# 3   1    2017  Hyderabad  ...          0              NaN  2017
# 4   1    2017  Hyderabad  ...          2              NaN  2017
#
# [5 rows x 36 columns]

# %%
data['inning'] = data['id'].astype(str)+(data['batting_team']).astype(str)
data.head()
# Out:
#    id  season       city  ... total_runs player_dismissed  year
# 0   1    2017  Hyderabad  ...          0              NaN  2017
# 1   1    2017  Hyderabad  ...          0              NaN  2017
# 2   1    2017  Hyderabad  ...          4              NaN  2017
# 3   1    2017  Hyderabad  ...          0              NaN  2017
# 4   1    2017  Hyderabad  ...          2              NaN  2017
#
# [5 rows x 36 columns]

# %%
data.loc[data["player_dismissed"].isnull()==True,"is_wicket"]=0
data.loc[data["player_dismissed"].isnull()==False,"is_wicket"]=1

# %%
list1 = data['inning'].unique()
(list1)
# Out:
# array(['1Sunrisers Hyderabad', '1Royal Challengers Bangalore',
#        '2Mumbai Indians', ..., '11414Chennai Super Kings',
#        '11415Mumbai Indians', '11415Chennai Super Kings'], dtype=object)

# %%
data2 = data.copy()
data2 = data2.groupby(by=['inning']).sum()['total_runs'].reset_index()
data2
# Out:
#                               inning  total_runs
# 0                100Delhi Daredevils         118
# 1                 100Kings XI Punjab          94
# 2                101Rajasthan Royals         197
# 3     101Royal Challengers Bangalore         132
# 4                 102Deccan Chargers         153
# ...                              ...         ...
# 1505              98Delhi Daredevils         194
# 1506         99Kolkata Knight Riders          67
# 1507                99Mumbai Indians          68
# 1508               9Delhi Daredevils         205
# 1509         9Rising Pune Supergiant         108
#
# [1510 rows x 2 columns]

# %%
data3 = pd.merge(left=data2, right=data, on='inning', how='right')
print(data3.shape)
data3.head()
# Out:
# (179078, 38)
#                  inning  total_runs_x  id  ...  player_dismissed  year is_wicket
# 0  1Sunrisers Hyderabad           207   1  ...               NaN  2017       0.0
# 1  1Sunrisers Hyderabad           207   1  ...               NaN  2017       0.0
# 2  1Sunrisers Hyderabad           207   1  ...               NaN  2017       0.0
# 3  1Sunrisers Hyderabad           207   1  ...               NaN  2017       0.0
# 4  1Sunrisers Hyderabad           207   1  ...               NaN  2017       0.0
#
# [5 rows x 38 columns]

# %%
container = pd.DataFrame()
for i in range(len(list1)):
    one_inning = data3.loc[data3['inning']==list1[i]]
    one_inning = one_inning.sort_values(['over', 'ball'], ascending=[True, True])
    one_inning = one_inning[['over','ball',
            'batsman_runs','extra_runs','total_runs_y','total_runs_x','batting_team','bowling_team','venue','is_wicket']].reset_index(drop=True)
    one_inning['CUMSUM_runs'] = one_inning['total_runs_y'].cumsum()
    one_inning['CUMSUM_wickets'] = one_inning['is_wicket'].cumsum()


    one_inning.tail()
    frame = [container,one_inning]
    container = pd.concat(frame)
print(data3.shape)
print(container.shape)
# Out:
# (179078, 38)
# (179078, 12)

# %%
data3 = container.copy()
container.head()
# Out:
#    over  ball  batsman_runs  ...  is_wicket  CUMSUM_runs  CUMSUM_wickets
# 0     2     1             0  ...        0.0            0             0.0
# 1     2     2             0  ...        0.0            0             0.0
# 2     2     3             4  ...        0.0            4             0.0
# 3     2     4             0  ...        0.0            4             0.0
# 4     2     5             0  ...        0.0            6             0.0
#
# [5 rows x 12 columns]

# %%
featureColumns = ['over','ball',
         'batsman_runs','extra_runs','total_runs_y','CUMSUM_runs','CUMSUM_wickets','venue','batting_team','bowling_team','is_wicket']
print(len(featureColumns))
# Out:
# 11

# %%
encoder=LabelEncoder()

# %%
data3["venue"]=encoder.fit_transform(data3["venue"])
data3["batting_team"]=encoder.fit_transform(data3["batting_team"])
data3["bowling_team"]=encoder.fit_transform(data3["bowling_team"])

# %%
data3.head()
# Out:
#    over  ball  batsman_runs  ...  is_wicket  CUMSUM_runs  CUMSUM_wickets
# 0     2     1             0  ...        0.0            0             0.0
# 1     2     2             0  ...        0.0            0             0.0
# 2     2     3             4  ...        0.0            4             0.0
# 3     2     4             0  ...        0.0            4             0.0
# 4     2     5             0  ...        0.0            6             0.0
#
# [5 rows x 12 columns]

# %%
data3['over_cur'] = data3['over'] + data3['ball']/10
data3 = data3[['over_cur',
               'batsman_runs','total_runs_y','CUMSUM_runs','CUMSUM_wickets','total_runs_x','batting_team','bowling_team','venue','is_wicket']]
data3.astype(float)
data3 = data3.fillna(-99.00)
data3.isnull().values.any()
import pandas as pd
from sklearn import preprocessing
data3.head()
# Out:
#    over_cur  batsman_runs  total_runs_y  ...  bowling_team  venue  is_wicket
# 0       2.1             0             0  ...            13     28        0.0
# 1       2.2             0             0  ...            13     28        0.0
# 2       2.3             4             4  ...            13     28        0.0
# 3       2.4             0             0  ...            13     28        0.0
# 4       2.5             0             2  ...            13     28        0.0
#
# [5 rows x 10 columns]

# %%
def custom_accuracy(y_test,y_pred,thresold=10):
    right = 0
    l = len(y_pred)
    for i in range(0,l):
        if(abs(y_pred[i]-y_test[i]) <= thresold):
            right += 1
        else:
          print('p',y_pred[i]*300,y_test[i]*300)
    return (right)

# %%
def custom_accuracy2(y_test,y_pred,thresold):
    right = 0
    l = len(y_pred)
    for i in range(0,l):
        if(abs(y_pred[i]-y_test[i]) <= thresold):
            right += 1
    return ((right/l)*100)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
X = data3.iloc[:,[0,1,2,3,4,6,7,8,9]].values #Input features
y = data3.iloc[:, 5]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=100,max_features=None)
model =rf.fit(X_train,y_train)
y_pred2 = rf.predict(X_test)
score = rf.score(X_test,y_test)*100
print("Score value:" , score)
# Out:
# Score value: 77.73720431986064

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout

# %%
model = Sequential()

model.add(Dense(43, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(22, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(11, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(1))

model.compile(loss='mse',optimizer='adam',metrics=['RootMeanSquaredError'])

# %%
history=model.fit(x=X_train, y=y_train, epochs=50, validation_data=(X_test,y_test))
# Out:
# Epoch 1/50
# 4198/4198 [==============================] - 12s 3ms/step - loss: 5852.8833 - root_mean_squared_error: 76.5041 - val_loss: 1166.7769 - val_root_mean_squared_error: 34.1581
# Epoch 2/50
# 4198/4198 [==============================] - 11s 3ms/step - loss: 4136.4575 - root_mean_squared_error: 64.3153 - val_loss: 1027.3871 - val_root_mean_squared_error: 32.0529
# Epoch 3/50
# 4198/4198 [==============================] - 11s 3ms/step - loss: 3673.8049 - root_mean_squared_error: 60.6119 - val_loss: 1068.0597 - val_root_mean_squared_error: 32.6812
# Epoch 4/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 3273.2800 - root_mean_squared_error: 57.2126 - val_loss: 887.2118 - val_root_mean_squared_error: 29.7861
# Epoch 5/50
# 4198/4198 [==============================] - 11s 3ms/step - loss: 2998.9084 - root_mean_squared_error: 54.7623 - val_loss: 898.8830 - val_root_mean_squared_error: 29.9814
# Epoch 6/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 2837.6514 - root_mean_squared_error: 53.2696 - val_loss: 915.1624 - val_root_mean_squared_error: 30.2517
# Epoch 7/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 2699.6790 - root_mean_squared_error: 51.9584 - val_loss: 809.8463 - val_root_mean_squared_error: 28.4578
# Epoch 8/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 2582.7803 - root_mean_squared_error: 50.8211 - val_loss: 816.6541 - val_root_mean_squared_error: 28.5772
# Epoch 9/50
# 4198/4198 [==============================] - 11s 3ms/step - loss: 2484.8101 - root_mean_squared_error: 49.8479 - val_loss: 794.7168 - val_root_mean_squared_error: 28.1907
# Epoch 10/50
# 4198/4198 [==============================] - 11s 3ms/step - loss: 2370.1831 - root_mean_squared_error: 48.6845 - val_loss: 779.0987 - val_root_mean_squared_error: 27.9123
# Epoch 11/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 2267.6221 - root_mean_squared_error: 47.6196 - val_loss: 747.2330 - val_root_mean_squared_error: 27.3356
# Epoch 12/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 2109.0476 - root_mean_squared_error: 45.9244 - val_loss: 700.6611 - val_root_mean_squared_error: 26.4700
# Epoch 13/50
# 4198/4198 [==============================] - 11s 3ms/step - loss: 1966.8740 - root_mean_squared_error: 44.3495 - val_loss: 736.5740 - val_root_mean_squared_error: 27.1399
# Epoch 14/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 1889.8351 - root_mean_squared_error: 43.4722 - val_loss: 762.3700 - val_root_mean_squared_error: 27.6110
# Epoch 15/50
# 4198/4198 [==============================] - 11s 3ms/step - loss: 1804.6638 - root_mean_squared_error: 42.4813 - val_loss: 733.0349 - val_root_mean_squared_error: 27.0746
# Epoch 16/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 1731.1598 - root_mean_squared_error: 41.6072 - val_loss: 734.6644 - val_root_mean_squared_error: 27.1047
# Epoch 17/50
# 4198/4198 [==============================] - 11s 3ms/step - loss: 1669.0067 - root_mean_squared_error: 40.8535 - val_loss: 715.8391 - val_root_mean_squared_error: 26.7552
# Epoch 18/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 1595.0039 - root_mean_squared_error: 39.9375 - val_loss: 671.1134 - val_root_mean_squared_error: 25.9059
# Epoch 19/50
# 4198/4198 [==============================] - 11s 3ms/step - loss: 1523.2108 - root_mean_squared_error: 39.0283 - val_loss: 654.5839 - val_root_mean_squared_error: 25.5848
# Epoch 20/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 1459.0840 - root_mean_squared_error: 38.1980 - val_loss: 684.7003 - val_root_mean_squared_error: 26.1668
# Epoch 21/50
# 4198/4198 [==============================] - 11s 3ms/step - loss: 1405.7570 - root_mean_squared_error: 37.4934 - val_loss: 638.0900 - val_root_mean_squared_error: 25.2604
# Epoch 22/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 1352.1080 - root_mean_squared_error: 36.7710 - val_loss: 653.1309 - val_root_mean_squared_error: 25.5564
# Epoch 23/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 1295.3943 - root_mean_squared_error: 35.9916 - val_loss: 656.4162 - val_root_mean_squared_error: 25.6206
# Epoch 24/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 1249.1047 - root_mean_squared_error: 35.3427 - val_loss: 655.9529 - val_root_mean_squared_error: 25.6116
# Epoch 25/50
# 4198/4198 [==============================] - 11s 3ms/step - loss: 1196.9701 - root_mean_squared_error: 34.5973 - val_loss: 619.6303 - val_root_mean_squared_error: 24.8924
# Epoch 26/50
# 4198/4198 [==============================] - 11s 3ms/step - loss: 1150.4668 - root_mean_squared_error: 33.9185 - val_loss: 625.5720 - val_root_mean_squared_error: 25.0114
# Epoch 27/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 1103.9913 - root_mean_squared_error: 33.2264 - val_loss: 638.0786 - val_root_mean_squared_error: 25.2602
# Epoch 28/50
# 4198/4198 [==============================] - 11s 3ms/step - loss: 1063.9343 - root_mean_squared_error: 32.6180 - val_loss: 620.7073 - val_root_mean_squared_error: 24.9140
# Epoch 29/50
# 4198/4198 [==============================] - 14s 3ms/step - loss: 1029.1427 - root_mean_squared_error: 32.0803 - val_loss: 624.0190 - val_root_mean_squared_error: 24.9804
# Epoch 30/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 996.2321 - root_mean_squared_error: 31.5631 - val_loss: 618.9080 - val_root_mean_squared_error: 24.8779
# Epoch 31/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 957.8509 - root_mean_squared_error: 30.9492 - val_loss: 610.8586 - val_root_mean_squared_error: 24.7156
# Epoch 32/50
# 4198/4198 [==============================] - 11s 3ms/step - loss: 927.9071 - root_mean_squared_error: 30.4616 - val_loss: 611.7392 - val_root_mean_squared_error: 24.7334
# Epoch 33/50
# 4198/4198 [==============================] - 13s 3ms/step - loss: 899.9395 - root_mean_squared_error: 29.9990 - val_loss: 611.8496 - val_root_mean_squared_error: 24.7356
# Epoch 34/50
# 4198/4198 [==============================] - 12s 3ms/step - loss: 873.6141 - root_mean_squared_error: 29.5570 - val_loss: 618.8578 - val_root_mean_squared_error: 24.8769
# Epoch 35/50
# 4198/4198 [==============================] - 11s 3ms/step - loss: 840.6076 - root_mean_squared_error: 28.9932 - val_loss: 599.6028 - val_root_mean_squared_error: 24.4868
# Epoch 36/50
# 4198/4198 [==============================] - 12s 3ms/step - loss: 827.1072 - root_mean_squared_error: 28.7595 - val_loss: 595.1057 - val_root_mean_squared_error: 24.3948
# Epoch 37/50
# 4198/4198 [==============================] - 11s 3ms/step - loss: 808.5396 - root_mean_squared_error: 28.4348 - val_loss: 612.3436 - val_root_mean_squared_error: 24.7456
# Epoch 38/50
# 4198/4198 [==============================] - 12s 3ms/step - loss: 786.1960 - root_mean_squared_error: 28.0392 - val_loss: 597.7228 - val_root_mean_squared_error: 24.4484
# Epoch 39/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 770.0417 - root_mean_squared_error: 27.7496 - val_loss: 593.9564 - val_root_mean_squared_error: 24.3712
# Epoch 40/50
# 4198/4198 [==============================] - 11s 3ms/step - loss: 757.4025 - root_mean_squared_error: 27.5209 - val_loss: 589.8032 - val_root_mean_squared_error: 24.2859
# Epoch 41/50
# 4198/4198 [==============================] - 12s 3ms/step - loss: 741.8949 - root_mean_squared_error: 27.2377 - val_loss: 593.5100 - val_root_mean_squared_error: 24.3621
# Epoch 42/50
# 4198/4198 [==============================] - 11s 3ms/step - loss: 731.9146 - root_mean_squared_error: 27.0539 - val_loss: 581.3519 - val_root_mean_squared_error: 24.1112
# Epoch 43/50
# 4198/4198 [==============================] - 11s 3ms/step - loss: 720.5218 - root_mean_squared_error: 26.8425 - val_loss: 588.2327 - val_root_mean_squared_error: 24.2535
# Epoch 44/50
# 4198/4198 [==============================] - 12s 3ms/step - loss: 715.1786 - root_mean_squared_error: 26.7428 - val_loss: 593.2422 - val_root_mean_squared_error: 24.3566
# Epoch 45/50
# 4198/4198 [==============================] - 11s 3ms/step - loss: 703.9474 - root_mean_squared_error: 26.5320 - val_loss: 589.8053 - val_root_mean_squared_error: 24.2859
# Epoch 46/50
# 4198/4198 [==============================] - 12s 3ms/step - loss: 699.3369 - root_mean_squared_error: 26.4450 - val_loss: 594.5420 - val_root_mean_squared_error: 24.3832
# Epoch 47/50
# 4198/4198 [==============================] - 12s 3ms/step - loss: 696.2551 - root_mean_squared_error: 26.3866 - val_loss: 598.3542 - val_root_mean_squared_error: 24.4613
# Epoch 48/50
# 4198/4198 [==============================] - 12s 3ms/step - loss: 692.0908 - root_mean_squared_error: 26.3076 - val_loss: 594.4557 - val_root_mean_squared_error: 24.3815
# Epoch 49/50
# 4198/4198 [==============================] - 10s 2ms/step - loss: 690.3134 - root_mean_squared_error: 26.2738 - val_loss: 598.9240 - val_root_mean_squared_error: 24.4729
# Epoch 50/50
# 4198/4198 [==============================] - 12s 3ms/step - loss: 686.7116 - root_mean_squared_error: 26.2052 - val_loss: 606.6313 - val_root_mean_squared_error: 24.6299

# %%
model_losses = pd.DataFrame(model.history.history)

# %%
plt.plot(model_losses['loss'])
plt.plot(model_losses['val_loss'])
plt.legend(["loss","val_loss"])
plt.xlabel('Epochs')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
predictions = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 18.541632

# %%
np.sqrt(mean_squared_error(y_test,predictions))
# Out:
# 24.629883

# %%
y_test = np.asarray(y_test).astype('float32')
predictions = np.asarray(predictions).astype('float32')
print("Custom accuracy: {:.3f} %".format(custom_accuracy2(y_test,predictions,10)))
# Out:
# Custom accuracy: 36.784 %

# %%
plt.scatter(y_test,predictions)
plt.xlabel('Actual scores')
plt.ylabel('Predicted scores')
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_32 (Dense)            (None, 43)                430
#
#  dropout_24 (Dropout)        (None, 43)                0
#
#  dense_33 (Dense)            (None, 22)                968
#
#  dropout_25 (Dropout)        (None, 22)                0
#
#  dense_34 (Dense)            (None, 11)                253
#
#  dropout_26 (Dropout)        (None, 11)                0
#
#  dense_35 (Dense)            (None, 1)                 12
#
# =================================================================
# Total params: 1,663
# Trainable params: 1,663
# Non-trainable params: 0
# _________________________________________________________________
